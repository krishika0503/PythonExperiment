# %% [markdown]
# Exp 4 - String and Sets

# %% [markdown]
# Github Repo Link
# https://github.com/krishika0503/PythonExperiment

# %% [markdown]
# Write a program to count and display number of capital letters in a given string.

# %%
s = input("Enter a string: ")
count = 0

for ch in s:
    if ch.isupper():
        count += 1

print("Number of capital letters:", count)
# Out:
# Enter a string: KfyhgAHSJH
# Number of capital letters: 6

# %% [markdown]
# Count number of vowels in a string.

# %%
s = input("Enter a string: ")
count = 0

for ch in s:
    if ch.lower() in "aeiou":
        count += 1

print("Number of vowels:", count)
# Out:
# Enter a string: Krisgijaaaa
# Number of vowels: 6

# %% [markdown]
# Input a sentence and print words in seperate lines

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()

for word in words:
    print(word)
# Out:
# Krishika
# is
# good

# %% [markdown]
# Write a program to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String transversal occurs from left to right and not right to left.

# %%
main_string = input("Enter the main string: ")
sub_string = input("Enter the substring to count: ")

occurrences = main_string.count(sub_string)

print(f"The substring '{sub_string}' occurs {occurrences} times in the main string.")
# Out:
# Enter the main string: World is beautiful just like the moon is beautiful
# Enter the substring to count: beautiful
# The substring 'beautiful' occurs 2 times in the main string.

# %% [markdown]
# Given a string containing both upper and lower case alphabets. Write a python program to count the number of occurences of each alphabet ( case insensitive ) and display the same

# %%
s = input("Enter a string: ")
s = s.upper()

count = {}

for ch in s:
  if ch.isalpha():
    count[ch] = count.get(ch, 0) + 1

for key in sorted(count):
  print(f"{key}: {count[key]}")
# Out:
# Enter a string: krishika12
# A: 1
# H: 1
# I: 2
# K: 2
# R: 1
# S: 1

# %% [markdown]
# Program to count number of unique words in a given sentence using sets

# %%
sentence = input("Enter a sentence: ")

sentence = sentence.lower()

words = sentence.split()

unique_words = set(words)

print("Unique words:", unique_words)
print("Number of unique words:", len(unique_words))
# Out:
# Enter a sentence: There are eight planets in the solar system
# Unique words: {'there', 'the', 'eight', 'planets', 'in', 'solar', 'are', 'system'}
# Number of unique words: 8

# %% [markdown]
# Create 2 sets s1 and s2 of n fruits each by taking input from user and find:
# a) Fruits which are in both sets s1 and s2
# b) Fruits only in s1 but not in s2
# c) Count of all fruits from s1 and s2

# %%
n = int(input("Enter number of fruits in each set: "))

s1 = set()
s2 = set()

print("Enter fruits for Set 1:")
for i in range(n):
    fruit = input()
    s1.add(fruit)

print("Enter fruits for Set 2:")
for i in range(n):
    fruit = input()
    s2.add(fruit)

# a) Fruits in both sets
common = s1 & s2

# b) Fruits only in s1
only_s1 = s1 - s2

# c) Count of all fruits (unique)
total_count = len(s1 | s2)

print("Fruits in both sets:", common)
print("Fruits only in s1:", only_s1)
print("Total count of all fruits:", total_count)
# Out:
# Enter number of fruits in each set: 4
# Enter fruits for Set 1:
# strawberry
# kiwi
# chicoo
# litchi
# Enter fruits for Set 2:
# mango
# pear
# guava
# apple
# Fruits in both sets: set()
# Fruits only in s1: {'litchi', 'strawberry', 'kiwi', 'chicoo'}
# Total count of all fruits: 8

# %% [markdown]
# Take two sets and apply various set operations on them :
# S1 = {Red ,yellow, orange , blue }
# S2 = {violet, blue , purple}

# %%
S1 = {"Red", "Yellow", "Orange", "Blue"}
S2 = {"Violet", "Blue", "Purple"}

print("Set 1:", S1)
print("Set 2:", S2)

# Union
print("Union:", S1 | S2)

# Intersection
print("Intersection:", S1 & S2)

# Difference
print("S1 - S2:", S1 - S2)
print("S2 - S1:", S2 - S1)

# Symmetric Difference
print("Symmetric Difference:", S1 ^ S2)
# Out:
# Set 1: {'Orange', 'Blue', 'Yellow', 'Red'}
# Set 2: {'Blue', 'Purple', 'Violet'}
# Union: {'Orange', 'Purple', 'Blue', 'Violet', 'Red', 'Yellow'}
# Intersection: {'Blue'}
# S1 - S2: {'Orange', 'Red', 'Yellow'}
# S2 - S1: {'Purple', 'Violet'}
# Symmetric Difference: {'Orange', 'Purple', 'Violet', 'Red', 'Yellow'}
